# %% [markdown]
# # 0.1 Explore data

# %% [markdown]
# #### Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import challenge_alaya.utils.paths as path
import janitor
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# #### Read data

# %%
input_data = path.data_raw_dir("data.csv")

# %%
### Cargar los datos ###
df = pd.read_csv(input_data)

# %%
# Conocer la forma de los datos
df.shape
# Out:
# (20631, 26)

# %%
# Conocer los datos nulos
df.isnull().sum()
# Out:
# unique_id    0
# unit_nr      0
# setting_1    0
# setting_2    0
# setting_3    0
# s_1          0
# s_2          0
# s_3          0
# s_4          0
# s_5          0
# s_6          0
# s_7          0
# s_8          0
# s_9          0
# s_10         0
# s_11         0
# s_12         0
# s_13         0
# s_14         0
# s_15         0
# s_16         0
# s_17         0
# s_18         0
# s_19         0
# s_20         0
# s_21         0
# dtype: int64

# %%
# Conocer el formato de los datos
df.dtypes
# Out:
# unique_id      int64
# unit_nr        int64
# setting_1    float64
# setting_2    float64
# setting_3    float64
# s_1          float64
# s_2          float64
# s_3          float64
# s_4          float64
# s_5          float64
# s_6          float64
# s_7          float64
# s_8          float64
# s_9          float64
# s_10         float64
# s_11         float64
# s_12         float64
# s_13         float64
# s_14         float64
# s_15         float64
# s_16         float64
# s_17           int64
# s_18           int64
# s_19         float64
# s_20         float64
# s_21         float64
# dtype: object

# %%
# Conociendo el conjunto de datos de forma resumida 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   unique_id  20631 non-null  int64
#  1   unit_nr    20631 non-null  int64
#  2   setting_1  20631 non-null  float64
#  3   setting_2  20631 non-null  float64
#  4   setting_3  20631 non-null  float64
#  5   s_1        20631 non-null  float64
#  6   s_2        20631 non-null  float64
#  7   s_3        20631 non-null  float64
#  8   s_4        20631 non-null  float64
#  9   s_5        20631 non-null  float64
#  10  s_6        20631 non-null  float64
#  11  s_7        20631 non-null  float64
#  12  s_8        20631 non-null  float64
#  13  s_9        20631 non-null  float64
#  14  s_10       20631 non-null  float64
#  15  s_11       20631 non-null  float64
#  16  s_12       20631 non-null  float64
#  17  s_13       20631 non-null  float64
#  18  s_14       20631 non-null  float64
#  19  s_15       20631 non-null  float64
#  20  s_16       20631 non-null  float64
#  21  s_17       20631 non-null  int64
#  22  s_18       20631 non-null  int64
#  23  s_19       20631 non-null  float64
#  24  s_20       20631 non-null  float64
#  25  s_21       20631 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 4.1 MB

# %%
# Visualizamos las primeras 5 filas del conjunto de datos
df.head()
# Out:
#    unique_id  unit_nr  setting_1  setting_2  setting_3     s_1     s_2  \
# 0        524       72     0.0020    -0.0001      100.0  518.67  643.66
# 1        525       72     0.0000     0.0001      100.0  518.67  643.90
# 2        526        6     0.0014    -0.0004      100.0  518.67  643.47
# 3        527       72     0.0007    -0.0003      100.0  518.67  643.91
# 4        528       72    -0.0000    -0.0002      100.0  518.67  643.30
#
#        s_3      s_4    s_5  ...    s_12     s_13     s_14    s_15  s_16  s_17  \
# 0  1606.65  1433.07  14.62  ...  519.44  2388.32  8099.94  8.5239  0.03   397
# 1  1598.73  1436.24  14.62  ...  520.18  2388.30  8101.49  8.5229  0.03   395
# 2  1600.63  1434.92  14.62  ...  518.98  2388.34  8102.82  8.5358  0.03   397
# 3  1597.72  1427.84  14.62  ...  519.48  2388.36  8103.27  8.5519  0.03   395
# 4  1605.50  1428.53  14.62  ...  519.45  2388.30  8103.77  8.5114  0.03   396
#
#    s_18   s_19   s_20     s_21
# 0  2388  100.0  38.46  22.9674
# 1  2388  100.0  38.45  23.0712
# 2  2388  100.0  38.42  22.9577
# 3  2388  100.0  38.46  23.1649
# 4  2388  100.0  38.39  23.0848
#
# [5 rows x 26 columns]

# %%
# Visualizamos las últimas 5 filas del conjunto de datos
df.tail()
# Out:
#        unique_id  unit_nr  setting_1  setting_2  setting_3     s_1     s_2  \
# 20626      21150       18    -0.0029    -0.0001      100.0  518.67  643.93
# 20627      21151       51     0.0015     0.0005      100.0  518.67  643.37
# 20628      21152        9    -0.0016     0.0004      100.0  518.67  644.04
# 20629      21153       48    -0.0025    -0.0005      100.0  518.67  644.02
# 20630      21154       51     0.0014     0.0004      100.0  518.67  644.11
#
#            s_3      s_4    s_5  ...    s_12     s_13     s_14    s_15  s_16  \
# 20626  1601.00  1428.08  14.62  ...  519.44  2388.39  8282.50  8.5132  0.03
# 20627  1602.44  1432.71  14.62  ...  520.36  2388.49  8288.26  8.5117  0.03
# 20628  1595.36  1428.43  14.62  ...  520.28  2388.56  8289.63  8.5156  0.03
# 20629  1609.54  1435.19  14.62  ...  520.53  2388.55  8290.25  8.4923  0.03
# 20630  1606.60  1428.55  14.62  ...  520.20  2388.54  8293.72  8.5306  0.03
#
#        s_17  s_18   s_19   s_20     s_21
# 20626   398  2388  100.0  38.50  23.0304
# 20627   398  2388  100.0  38.72  23.0834
# 20628   399  2388  100.0  38.45  23.0284
# 20629   398  2388  100.0  38.45  23.0188
# 20630   397  2388  100.0  38.39  23.0958
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Explore data

# %%
# Estadística descriptiva del conjunto de datos
df.describe()
# Out:
#           unique_id       unit_nr     setting_1     setting_2  setting_3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000    20631.0
# mean   10839.000000     51.506568     -0.000009      0.000002      100.0
# std     5955.801038     29.227633      0.002187      0.000293        0.0
# min      524.000000      1.000000     -0.008700     -0.000600      100.0
# 25%     5681.500000     26.000000     -0.001500     -0.000200      100.0
# 50%    10839.000000     52.000000      0.000000      0.000000      100.0
# 75%    15996.500000     77.000000      0.001500      0.000300      100.0
# max    21154.000000    100.000000      0.008700      0.000600      100.0
#
#                 s_1           s_2           s_3           s_4           s_5  \
# count  2.063100e+04  20631.000000  20631.000000  20631.000000  2.063100e+04
# mean   5.186700e+02    642.680934   1590.523119   1408.933782  1.462000e+01
# std    6.537152e-11      0.500053      6.131150      9.000605  3.394700e-12
# min    5.186700e+02    641.210000   1571.040000   1382.250000  1.462000e+01
# 25%    5.186700e+02    642.325000   1586.260000   1402.360000  1.462000e+01
# 50%    5.186700e+02    642.640000   1590.100000   1408.040000  1.462000e+01
# 75%    5.186700e+02    643.000000   1594.380000   1414.555000  1.462000e+01
# max    5.186700e+02    644.530000   1616.910000   1441.490000  1.462000e+01
#
#        ...          s_12          s_13          s_14          s_15  \
# count  ...  20631.000000  20631.000000  20631.000000  20631.000000
# mean   ...    521.413470   2388.096152   8143.752722      8.442146
# std    ...      0.737553      0.071919     19.076176      0.037505
# min    ...    518.690000   2387.880000   8099.940000      8.324900
# 25%    ...    520.960000   2388.040000   8133.245000      8.414900
# 50%    ...    521.480000   2388.090000   8140.540000      8.438900
# 75%    ...    521.950000   2388.140000   8148.310000      8.465600
# max    ...    523.380000   2388.560000   8293.720000      8.584800
#
#                s_16          s_17     s_18     s_19          s_20  \
# count  2.063100e+04  20631.000000  20631.0  20631.0  20631.000000
# mean   3.000000e-02    393.210654   2388.0    100.0     38.816271
# std    1.556432e-14      1.548763      0.0      0.0      0.180746
# min    3.000000e-02    388.000000   2388.0    100.0     38.140000
# 25%    3.000000e-02    392.000000   2388.0    100.0     38.700000
# 50%    3.000000e-02    393.000000   2388.0    100.0     38.830000
# 75%    3.000000e-02    394.000000   2388.0    100.0     38.950000
# max    3.000000e-02    400.000000   2388.0    100.0     39.430000
#
#                s_21
# count  20631.000000
# mean      23.289705
# std        0.108251
# min       22.894200
# 25%       23.221800
# 50%       23.297900
# 75%       23.366800
# max       23.618400
#
# [8 rows x 26 columns]

# %%
df['unit_nr'].value_counts()
# Out:
# 69    362
# 92    341
# 96    336
# 67    313
# 83    293
#      ...
# 24    147
# 70    137
# 57    137
# 91    135
# 39    128
# Name: unit_nr, Length: 100, dtype: int64

# %%
import challenge_alaya.visualization.visualize as visualize

# %%
visualize.plot_work_by_motor(df)

# %%
visualize.plot_correlation_heatmap(df)
